# %% [markdown]
# Here I preprocess the raw data again
# - additionally - standard deviations, means, max, mins, protein mean pathogenicity
# - normalization of ESM1b data - global - read paper thoroughly and how did the AlphaMissense normalized the scores.
# - pick high pathogenic variants per residue above certain threshold and analyze their scale values of AAclust

# %% [markdown]
# ### Imports and data pathways

# %%
import os  # Only if file operations are needed
import pandas as pd
import numpy as np
#import seaborn as sns
import matplotlib.pyplot as plt
from pathlib import Path
from tqdm.notebook import tqdm

# %%
os.chdir("/Users/doma/Documents/Bachelor_Arbeit/Code") 
# 1. Set up paths relative to notebook location
project_root = Path.cwd()  # assumes you run the notebook from /Code

esm_pathway = project_root / "data" / "raw" / "ALL_hum_isoforms_ESM1b_LLR"
amiss_pathway = project_root / "data" / "raw" / "AlphaMissense_csv"
human_nout_proteome_pathway = project_root / "data" / "processed" / "Human_N_Out_Proteome.csv"
all_esm1b_proteins_fp = project_root / "data" / "raw" / "000_uniprot_df.csv"

# 2. Load protein list
all_esm1b_proteins = pd.read_csv(all_esm1b_proteins_fp)
human_nout_proteome = pd.read_csv(human_nout_proteome_pathway)

# %% [markdown]
# ### Normalization of ESM1b LLR Scores

# %% [markdown]
# #### Code to find the lowest LLR score

# %%
# find the most pathogenic LLR score in random .csv files in esm_pathway
# Select 1000 random entries from all_esm1b_proteins
random_entries = all_esm1b_proteins.sample(n=1000, random_state=42)['id']

# Initialize a variable to store the highest score
highest_score = 0

# Iterate over the selected entries again to find the highest score in the matrix
for entry in random_entries:
    esm_file_path = os.path.join(esm_pathway, f"{entry}_LLR.csv")
    
    if os.path.exists(esm_file_path):
        esm_data = pd.read_csv(esm_file_path, index_col=0)
        
        # Update the highest score if a higher score is found
        highest_score = min(highest_score, esm_data.to_numpy().min())

print(f"Highest score among all matrices: {highest_score}")
# Out:
# Highest score among all matrices: -29.592

# %% [markdown]
# #### Code to find 1st and 99th percentile of ESM1b global LLR scores

# %%
# Calculate the 1st and 99th percentile 
n = 1000  # You can adjust the value of n as needed
selected_entries = all_esm1b_proteins.sample(n, random_state=42)['id']

# Initialize a list to store all scores
all_scores = []

# Iterate over the selected entries and collect scores
for entry in selected_entries:
    esm_file_path = os.path.join(esm_pathway, f"{entry}_LLR.csv")
    
    if os.path.exists(esm_file_path):
        esm_data = pd.read_csv(esm_file_path, index_col=0)

        # Flatten and filter out zeros
        scores = esm_data.to_numpy().flatten()

        # Exclude LLR=0 values
        scores_nonzero = scores[scores != 0]
        all_scores.extend(scores_nonzero)



# Calculate the 1st and 99th percentiles
percentile_1 = np.percentile(all_scores, 0.5)
percentile_99 = np.percentile(all_scores, 99.5)
percentile_5 = np.percentile(all_scores, 5)
print(f"0.5th Percentile: {percentile_1:.2f}, 99.5th Percentile: {percentile_99:.2f}, 5th Percentile: {percentile_5:.2f}")
# Out:
# 0.5th Percentile: -20.60, 99.5th Percentile: -0.65, 5th Percentile: -17.24

# %%
# Plot the distribution of scores
plt.figure(figsize=(12, 8))
sns.histplot(all_scores, bins=50, kde=True, color='blue', alpha=0.7, edgecolor='black', linewidth=0.5)
plt.axvline(percentile_1, color='red', linestyle='--', linewidth=1.5, label='1st Percentile')
plt.axvline(percentile_99, color='red', linestyle='--', linewidth=1.5, label='99th Percentile')

# Add annotations for percentiles
plt.text(percentile_1 + 4, plt.ylim()[1] * 0.8, f"0.5th Percentile\n({percentile_1:.2f})", color='red', fontsize=14, ha='center', fontweight='bold')
plt.text(percentile_99 + 4, plt.ylim()[1] * 0.8, f"99.5th Percentile\n({percentile_99:.2f})", color='red', fontsize=14, ha='center', fontweight='bold')

# Improve aesthetics
plt.title(f'Distribution of LLR Scores for {n} Proteins', fontsize=16, fontweight='bold')
plt.xlabel('Score', fontsize=14)
plt.ylabel('Frequency', fontsize=14)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)

# Show the plot
plt.tight_layout()
plt.show()

# Print percentiles
print(f"0.5th Percentile: {percentile_1:.2f}, 99.5th Percentile: {percentile_99:.2f}")
# Out:
# 0.5th Percentile: -20.60, 99.5th Percentile: -0.65

# %% [markdown]
# Abbildung, die normalizierung erklärt und die
# Alphamissense mappen auf die Kategorien von Clinvar
#
# esm1b pathogen threshold
# esm1b

# %% [markdown]
# #### Normalization Step

# %%
print(f"0.5th Percentile: {percentile_1:.2f}, 99.5th Percentile: {percentile_99:.2f}")

# now take all the 1500 proteins ['entry'] from human_nout_proteome and normalize every
# LLR score and create new normalized .csv file in another folder 

save_folder = project_root / "data" / "processed" / "ESM1b_LLR_Normalized_Human_Nout_Proteome"
esm1b_missing_entries = []


# Exclude zero: if value == 0, keep it; else, normalize
def normalize_llr(x):
    if x == 0:
        return np.nan   # or np.nan if you want to mask it!
    else:
        return round((percentile_99 - x) / (percentile_99 - percentile_1), 7)



for entry in tqdm(human_nout_proteome['entry'], desc="Normalizing proteins"):

    esm_protein_path = os.path.join(esm_pathway, f"{entry}_LLR.csv" )

    if os.path.exists(esm_protein_path):

        # load the dataframe
        protein = pd.read_csv(esm_protein_path)

        # all columns without the first label one
        cols_to_normalize = protein.columns[1:]

       
        # for each element in esm1b protein pd apply normalization
        protein[cols_to_normalize] = protein[cols_to_normalize].map(normalize_llr)
            

        # Save the normalized file
        protein.to_csv(save_folder / f"{entry}_normalized.csv", index=False)
        print(f"Protein {entry} was successfully normalized")


    else:
        print(f"Protein {entry} is not in ESM1b database")
        esm1b_missing_entries.append(entry)



pd.DataFrame({'missing_entry': esm1b_missing_entries}).to_csv(
    save_folder / "esm1b_missing_entries.csv", index=False
    )
# Out:
# 0.5th Percentile: -20.60, 99.5th Percentile: -0.65
# Normalizing proteins:   0%|          | 0/1534 [00:00<?, ?it/s]
# Protein P16150 was successfully normalized
# Protein P28827 was successfully normalized
# Protein P10586 was successfully normalized
# Protein Q06418 was successfully normalized
# Protein P54764 was successfully normalized
# Protein P19022 was successfully normalized
# Protein O60469 was successfully normalized
# Protein Q14118 was successfully normalized
# Protein P09603 was successfully normalized
# Protein P23468 was successfully normalized
# Protein Q9UM47 was successfully normalized
# Protein Q04721 was successfully normalized
# Protein P05067 was successfully normalized
# Protein P12830 was successfully normalized
# Protein Q06481 was successfully normalized
# Protein O14522 was successfully normalized
# Protein P08581 was successfully normalized
# Protein P22223 was successfully normalized
# Protein Q86VB7 was successfully normalized
# Protein Q15303 was successfully normalized
# Protein Q15223 was successfully normalized
# Protein Q9HCJ2 was successfully normalized
# Protein Q8TD84 was successfully normalized
# Protein P04439 was successfully normalized
# Protein Q9NZR2 was successfully normalized
# Protein P16070 was successfully normalized
# Protein P17342 was successfully normalized
# Protein Q86YL7 was successfully normalized
# Protein P16422 was successfully normalized
# Protein P01893 was successfully normalized
# Protein P30530 was successfully normalized
# Protein P30511 was successfully normalized
# Protein P55283 was successfully normalized
# Protein Q07954 was successfully normalized
# Protein Q13308 was successfully normalized
# Protein O60330 was successfully normalized
# Protein P35590 was successfully normalized
# Protein Q8N423 was successfully normalized
# Protein Q8NHL6 was successfully normalized
# Protein O75056 was successfully normalized
# Protein Q9UK00 was successfully normalized
# Protein P46531 was successfully normalized
# Protein O75022 was successfully normalized
# Protein Q15109 was successfully normalized
# Protein Q12866 was successfully normalized
# Protein Q9NT99 was successfully normalized
# Protein P19021 was successfully normalized
# Protein Q9BUF7 was successfully normalized
# Protein Q9Y5H0 was successfully normalized
# Protein Q9HCM2 was successfully normalized
# Protein P17948 was successfully normalized
# Protein P29317 was successfully normalized
# Protein P54753 was successfully normalized
# Protein P78324 was successfully normalized
# Protein Q9HBW1 was successfully normalized
# Protein P35613 was successfully normalized
# Protein Q92692 was successfully normalized
# Protein P51693 was successfully normalized
# Protein P43146 was successfully normalized
# Protein Q50LG9 was successfully normalized
# Protein P21709 was successfully normalized
# Protein Q9Y5G9 was successfully normalized
# Protein Q92859 was successfully normalized
# Protein Q9Y6N7 was successfully normalized
# Protein Q8WWV6 was successfully normalized
# Protein P08069 was successfully normalized
# Protein Q8NFZ4 was successfully normalized
# Protein Q9UBG0 was successfully normalized
# Protein Q9HD43 was successfully normalized
# Protein P34741 was successfully normalized
# Protein P22897 was successfully normalized
# Protein Q13291 was successfully normalized
# Protein Q9Y5G8 was successfully normalized
# Protein Q6UVK1 was successfully normalized
# Protein Q685J3 was successfully normalized
# Protein P25092 was successfully normalized
# Protein P27930 was successfully normalized
# Protein P06729 was successfully normalized
# Protein Q9Y5G5 was successfully normalized
# Protein P33151 was successfully normalized
# Protein P40967 was successfully normalized
# Protein Q9UGT4 was successfully normalized
# Protein Q15262 was successfully normalized
# Protein P78310 was successfully normalized
# Protein O95754 was successfully normalized
# Protein A6BM72 was successfully normalized
# Protein Q9UKJ1 was successfully normalized
# Protein Q9HDB5 was successfully normalized
# Protein Q9Y4C0 was successfully normalized
# Protein P58400 was successfully normalized
# Protein Q9ULB1 was successfully normalized
# Protein P11912 was successfully normalized
# Protein Q96PL5 was successfully normalized
# Protein Q9H4D0 was successfully normalized
# Protein P42081 was successfully normalized
# Protein P58401 was successfully normalized
# Protein Q9P2S2 was successfully normalized
# Protein P37023 was successfully normalized
# Protein Q8N2Q7 was successfully normalized
# Protein P08138 was successfully normalized
# Protein Q6ZV29 was successfully normalized
# Protein O00548 was successfully normalized
# Protein P78325 was successfully normalized
# Protein Q12913 was successfully normalized
# Protein Q96PQ0 was successfully normalized
# Protein Q30201 was successfully normalized
# Protein O43184 was successfully normalized
# Protein P18433 was successfully normalized
# Protein P00533 was successfully normalized
# Protein P31431 was successfully normalized
# Protein P04626 was successfully normalized
# Protein Q9Y639 was successfully normalized
# Protein Q9UEF7 was successfully normalized
# Protein Q12864 was successfully normalized
# Protein Q9Y5G6 was successfully normalized
# Protein P51512 was successfully normalized
# Protein P0C7U0 was successfully normalized
# Protein P19438 was successfully normalized
# Protein Q8TBP5 was successfully normalized
# Protein Q6UXG8 was successfully normalized
# Protein P23469 was successfully normalized
# Protein Q2M385 was successfully normalized
# Protein P29323 was successfully normalized
# Protein Q96DU3 was successfully normalized
# Protein P08887 was successfully normalized
# Protein Q92673 was successfully normalized
# Protein Q9C0C4 was successfully normalized
# Protein P25445 was successfully normalized
# Protein Q9NZ94 was successfully normalized
# Protein O43157 was successfully normalized
# Protein P12318 was successfully normalized
# Protein P31995 was successfully normalized
# Protein P01833 was successfully normalized
# Protein P18827 was successfully normalized
# Protein P14151 was successfully normalized
# Protein Q9UKJ0 was successfully normalized
# Protein Q8N0W4 was successfully normalized
# Protein Q8NFZ3 was successfully normalized
# Protein P16109 was successfully normalized
# Protein P55899 was successfully normalized
# Protein P52799 was successfully normalized
# Protein O15389 was successfully normalized
# Protein Q8N8Z6 was successfully normalized
# Protein Q5R3F8 was successfully normalized
# Protein P55285 was successfully normalized
# Protein Q96J84 was successfully normalized
# Protein P01130 was successfully normalized
# Protein Q9H2U9 was successfully normalized
# Protein Q96KG7 was successfully normalized
# Protein Q16827 was successfully normalized
# Protein P55287 was successfully normalized
# Protein O75023 was successfully normalized
# Protein P13747 was successfully normalized
# Protein Q6UXK5 was successfully normalized
# Protein Q9BRK3 was successfully normalized
# Protein Q9Y5G7 was successfully normalized
# Protein Q9Y5G4 was successfully normalized
# Protein P29016 was successfully normalized
# Protein Q9NYJ7 was successfully normalized
# Protein Q9UIW2 was successfully normalized
# Protein O15146 was successfully normalized
# Protein Q86T20 was successfully normalized
# Protein Q7Z408 was successfully normalized
# Protein O75051 was successfully normalized
# Protein Q9BYE9 was successfully normalized
# Protein Q14114 was successfully normalized
# Protein Q9H7M9 was successfully normalized
# Protein Q86YW5 was successfully normalized
# Protein P15382 was successfully normalized
# Protein P32004 was successfully normalized
# Protein Q16620 was successfully normalized
# Protein Q9NS68 was successfully normalized
# Protein Q8TDW7 was successfully normalized
# Protein Q6UXZ0 was successfully normalized
# Protein Q9HCK4 was successfully normalized
# Protein O75096 was successfully normalized
# Protein Q99466 was successfully normalized
# Protein Q9Y5H2 was successfully normalized
# Protein Q9Y5G0 was successfully normalized
# Protein P40126 was successfully normalized
# Protein P11717 was successfully normalized
# Protein Q8IZJ1 was successfully normalized
# Protein O94856 was successfully normalized
# Protein Q9NZV1 was successfully normalized
# Protein P41217 was successfully normalized
# Protein P15514 was successfully normalized
# Protein Q9Y5G3 was successfully normalized
# Protein Q3MIP1 was successfully normalized
# Protein O94985 was successfully normalized
# Protein Q96RJ3 was successfully normalized
# Protein Q96MS0 was successfully normalized
# Protein Q9UJ99 was successfully normalized
# Protein Q9HBT6 was successfully normalized
# Protein P09758 was successfully normalized
# Protein Q9Y5H3 was successfully normalized
# Protein Q99523 was successfully normalized
# Protein P14209 was successfully normalized
# Protein Q9ULB4 was successfully normalized
# Protein O60896 was successfully normalized
# Protein P21754 was successfully normalized
# Protein Q9UQV4 was successfully normalized
# Protein Q96D42 was successfully normalized
# Protein Q6UXC1 was successfully normalized
# Protein Q08345 was successfully normalized
# Protein Q6ZN44 was successfully normalized
# Protein Q8IY17 was successfully normalized
# Protein Q9H2A7 was successfully normalized
# Protein P26842 was successfully normalized
# Protein O95185 was successfully normalized
# Protein P11279 was successfully normalized
# Protein Q9Y6N8 was successfully normalized
# Protein Q495A1 was successfully normalized
# Protein O94826 was successfully normalized
# Protein Q9Y5F9 was successfully normalized
# Protein Q9Y4D7 was successfully normalized
# Protein P54762 was successfully normalized
# Protein Q15762 was successfully normalized
# Protein O75581 was successfully normalized
# Protein P43121 was successfully normalized
# Protein O43699 was successfully normalized
# Protein A6NMB1 was successfully normalized
# Protein Q13634 was successfully normalized
# Protein P04440 was successfully normalized
# Protein Q9ULX7 was successfully normalized
# Protein O14669 was successfully normalized
# Protein Q96PZ7 was successfully normalized
# Protein Q5ZPR3 was successfully normalized
# Protein Q9NQS3 was successfully normalized
# Protein O76095 was successfully normalized
# Protein P54760 was successfully normalized
# Protein Q96PX8 was successfully normalized
# Protein Q9HC56 was successfully normalized
# Protein P34810 was successfully normalized
# Protein P55289 was successfully normalized
# Protein Q9Y5H1 was successfully normalized
# Protein O00533 was successfully normalized
# Protein Q6UWI2 was successfully normalized
# Protein P55291 was successfully normalized
# Protein Q8NFM7 was successfully normalized
# Protein Q86UP0 was successfully normalized
# Protein Q9UN71 was successfully normalized
# Protein P20273 was successfully normalized
# Protein Q9ULB5 was successfully normalized
# Protein Q9BZA7 was successfully normalized
# Protein Q9BZA8 was successfully normalized
# Protein P21583 was successfully normalized
# Protein Q9NZQ7 was successfully normalized
# Protein Q9Y5H4 was successfully normalized
# Protein P98164 was successfully normalized
# Protein Q08174 was successfully normalized
# Protein Q5DID0 was successfully normalized
# Protein Q9H3T3 was successfully normalized
# Protein Q16655 was successfully normalized
# Protein Q13332 was successfully normalized
# Protein Q9Y219 was successfully normalized
# Protein P05538 was successfully normalized
# Protein P22607 was successfully normalized
# Protein Q92823 was successfully normalized
# Protein Q6UXV0 was successfully normalized
# Protein P29322 was successfully normalized
# Protein Q02223 was successfully normalized
# Protein P19235 was successfully normalized
# Protein Q9Y5F8 was successfully normalized
# Protein Q9ULT6 was successfully normalized
# Protein A4D2H0 was successfully normalized
# Protein Q8IX94 was successfully normalized
# Protein Q86UF2 was successfully normalized
# Protein P0CG41 was successfully normalized
# Protein A4FU28 was successfully normalized
# Protein P78552 was successfully normalized
# Protein Q8TC27 was successfully normalized
# Protein Q19T08 was successfully normalized
# Protein Q02763 was successfully normalized
# Protein P78504 was successfully normalized
# Protein P50281 was successfully normalized
# Protein O60245 was successfully normalized
# Protein Q8WWG9 was successfully normalized
# Protein A6NC97 was successfully normalized
# Protein Q95460 was successfully normalized
# Protein O94898 was successfully normalized
# Protein P14616 was successfully normalized
# Protein P23471 was successfully normalized
# Protein Q2VWP7 was successfully normalized
# Protein Q9Y5G1 was successfully normalized
# Protein P15941 was successfully normalized
# Protein P58511 was successfully normalized
# Protein Q6UXZ4 was successfully normalized
# Protein Q6IA17 was successfully normalized
# Protein O14511 was successfully normalized
# Protein O60939 was successfully normalized
# Protein Q96PE5 was successfully normalized
# Protein P01889 was successfully normalized
# Protein Q02297 was successfully normalized
# Protein Q9NQ25 was successfully normalized
# Protein Q6J9G0 was successfully normalized
# Protein Q9BQ51 was successfully normalized
# Protein Q8WY21 was successfully normalized
# Protein Q13740 was successfully normalized
# Protein Q96PJ5 was successfully normalized
# Protein O43506 was successfully normalized
# Protein Q96AP7 was successfully normalized
# Protein Q9UPZ6 was successfully normalized
# Protein Q16288 was successfully normalized
# Protein O14917 was successfully normalized
# Protein P98172 was successfully normalized
# Protein Q9NR61 was successfully normalized
# Protein P16581 was successfully normalized
# Protein P51805 was successfully normalized
# Protein Q6EMK4 was successfully normalized
# Protein Q9Y5G2 was successfully normalized
# Protein P17927 was successfully normalized
# Protein Q9UPU3 was successfully normalized
# Protein Q96CP6 was successfully normalized
# Protein P35916 was successfully normalized
# Protein O94991 was successfully normalized
# Protein Q12907 was successfully normalized
# Protein Q86XK7 was successfully normalized
# Protein P28908 was successfully normalized
# Protein Q92729 was successfully normalized
# Protein Q6UY09 was successfully normalized
# Protein Q9NPY3 was successfully normalized
# Protein P01589 was successfully normalized
# Protein P13224 was successfully normalized
# Protein A8MVZ5 was successfully normalized
# Protein P98153 was successfully normalized
# Protein P29376 was successfully normalized
# Protein A2A2V5 was successfully normalized
# Protein Q13445 was successfully normalized
# Protein Q14956 was successfully normalized
# Protein O00238 was successfully normalized
# Protein O60667 was successfully normalized
# Protein Q9BQS7 was successfully normalized
# Protein P06213 was successfully normalized
# Protein Q8TDQ0 was successfully normalized
# Protein Q9H156 was successfully normalized
# Protein Q9C0A0 was successfully normalized
# Protein Q92637 was successfully normalized
# Protein Q8IYV9 was successfully normalized
# Protein Q96JQ0 was successfully normalized
# Protein Q9HCL0 was successfully normalized
# Protein P43489 was successfully normalized
# Protein P35968 was successfully normalized
# Protein Q96A28 was successfully normalized
# Protein Q5JZY3 was successfully normalized
# Protein P24394 was successfully normalized
# Protein Q9UBV2 was successfully normalized
# Protein Q9Y279 was successfully normalized
# Protein Q14954 was successfully normalized
# Protein P11362 was successfully normalized
# Protein P01920 was successfully normalized
# Protein P12314 was successfully normalized
# Protein P40189 was successfully normalized
# Protein Q14953 was successfully normalized
# Protein Q9UM73 was successfully normalized
# Protein P43628 was successfully normalized
# Protein Q16790 was successfully normalized
# Protein Q96HA4 was successfully normalized
# Protein O60486 was successfully normalized
# Protein Q8TDF5 was successfully normalized
# Protein P01730 was successfully normalized
# Protein Q9ULL4 was successfully normalized
# Protein Q6UX15 was successfully normalized
# Protein P25942 was successfully normalized
# Protein P16871 was successfully normalized
# Protein Q9Y5E9 was successfully normalized
# Protein Q9UMZ3 was successfully normalized
# Protein Q16849 was successfully normalized
# Protein P0DKB5 was successfully normalized
# Protein Q9NPF0 was successfully normalized
# Protein Q96RD9 was successfully normalized
# Protein P34910 was successfully normalized
# Protein Q6P1J6 was successfully normalized
# Protein Q15363 was successfully normalized
# Protein Q5T2D2 was successfully normalized
# Protein Q9H6B4 was successfully normalized
# Protein Q9H5V8 was successfully normalized
# Protein Q8IWV1 was successfully normalized
# Protein Q14517 was successfully normalized
# Protein O95727 was successfully normalized
# Protein Q9H9K5 was successfully normalized
# Protein O95866 was successfully normalized
# Protein Q9BVV8 was successfully normalized
# Protein P20594 was successfully normalized
# Protein Q86VZ4 was successfully normalized
# Protein P07204 was successfully normalized
# Protein Q14626 was successfully normalized
# Protein Q9BQT9 was successfully normalized
# Protein Q14952 was successfully normalized
# Protein P28906 was successfully normalized
# Protein Q9H159 was successfully normalized
# Protein Q9UKN1 was successfully normalized
# Protein Q86XX4 was successfully normalized
# Protein O60279 was successfully normalized
# Protein P10747 was successfully normalized
# Protein A0A087WTH5 was successfully normalized
# Protein P49755 was successfully normalized
# Protein Q9NS62 was successfully normalized
# Protein Q6DN72 was successfully normalized
# Protein Q0VAQ4 was successfully normalized
# Protein Q9BZD7 was successfully normalized
# Protein A0A1B0GU29 was successfully normalized
# Protein Q96P31 was successfully normalized
# Protein Q9NRJ7 was successfully normalized
# Protein Q96NY8 was successfully normalized
# Protein P01911 was successfully normalized
# Protein P79483 was successfully normalized
# Protein Q86XR5 was successfully normalized
# Protein P32942 was successfully normalized
# Protein Q9BZ76 was successfully normalized
# Protein Q9P2E7 was successfully normalized
# Protein P42702 was successfully normalized
# Protein Q9UHC6 was successfully normalized
# Protein Q9NP84 was successfully normalized
# Protein Q9Y5F2 was successfully normalized
# Protein Q9Y5E5 was successfully normalized
# Protein Q9Y5E4 was successfully normalized
# Protein Q9Y5E3 was successfully normalized
# Protein Q14761 was successfully normalized
# Protein Q3KPI0 was successfully normalized
# Protein A8MVW5 was successfully normalized
# Protein P30203 was successfully normalized
# Protein Q8IW52 was successfully normalized
# Protein Q7KYR7 was successfully normalized
# Protein P08F94 was successfully normalized
# Protein Q96NI6 was successfully normalized
# Protein Q96JA1 was successfully normalized
# Protein O94933 was successfully normalized
# Protein P18627 was successfully normalized
# Protein Q16832 was successfully normalized
# Protein Q9UBS9 was successfully normalized
# Protein O75264 was successfully normalized
# Protein P43631 was successfully normalized
# Protein Q6P9G4 was successfully normalized
# Protein Q8NET5 was successfully normalized
# Protein I3L273 was successfully normalized
# Protein Q9UN66 was successfully normalized
# Protein Q8WVN6 was successfully normalized
# Protein O00453 was successfully normalized
# Protein P55286 was successfully normalized
# Protein Q15375 was successfully normalized
# Protein P43632 was successfully normalized
# Protein Q92956 was successfully normalized
# Protein Q92932 was successfully normalized
# Protein O14763 was successfully normalized
# Protein P07333 was successfully normalized
# Protein Q8NCU8 was successfully normalized
# Protein P98155 was successfully normalized
# Protein Q9NRM6 was successfully normalized
# Protein O43819 was successfully normalized
# Protein Q13641 was successfully normalized
# Protein Q9ULH4 was successfully normalized
# Protein Q8N3J6 was successfully normalized
# Protein O15031 was successfully normalized
# Protein P13765 was successfully normalized
# Protein Q9BZW8 was successfully normalized
# Protein Q8NEQ5 was successfully normalized
# Protein Q4KMG0 was successfully normalized
# Protein O43155 was successfully normalized
# Protein Q8N743 was successfully normalized
# Protein Q9H2B2 was successfully normalized
# Protein Q16671 was successfully normalized
# Protein Q5IJ48 was successfully normalized
# Protein P20023 was successfully normalized
# Protein Q6UW88 was successfully normalized
# Protein P0DTU4 was successfully normalized
# Protein P0DSE2 is not in ESM1b database
# Protein A0A5B9 was successfully normalized
# Protein Q9BYF1 was successfully normalized
# Protein Q5SQ64 was successfully normalized
# Protein O00299 was successfully normalized
# Protein Q9NNZ3 was successfully normalized
# Protein O95297 was successfully normalized
# Protein Q9UJ90 was successfully normalized
# Protein P16435 was successfully normalized
# Protein Q9H3R2 was successfully normalized
# Protein Q8NHJ6 was successfully normalized
# Protein Q14703 was successfully normalized
# Protein O60894 was successfully normalized
# Protein Q6NUJ2 was successfully normalized
# Protein Q3MIW9 was successfully normalized
# Protein Q9UN70 was successfully normalized
# Protein P17643 was successfully normalized
# Protein P35070 was successfully normalized
# Protein Q9Y6J6 was successfully normalized
# Protein P20036 was successfully normalized
# Protein Q9BY67 was successfully normalized
# Protein Q86Z14 was successfully normalized
# Protein Q96NU0 was successfully normalized
# Protein Q99075 was successfully normalized
# Protein P43626 was successfully normalized
# Protein P43627 was successfully normalized
# Protein Q96IQ7 was successfully normalized
# Protein Q9BUR5 was successfully normalized
# Protein O43570 was successfully normalized
# Protein O00168 was successfully normalized
# Protein P13726 was successfully normalized
# Protein Q6ZRP7 was successfully normalized
# Protein Q8IWB1 was successfully normalized
# Protein Q9HC73 was successfully normalized
# Protein Q30154 was successfully normalized
# Protein Q7L0X0 was successfully normalized
# Protein Q9Y5E2 was successfully normalized
# Protein Q7Z5B4 was successfully normalized
# Protein Q9H7Z7 was successfully normalized
# Protein Q9BYH1 was successfully normalized
# Protein Q96FE7 was successfully normalized
# Protein P58549 was successfully normalized
# Protein Q9NR16 was successfully normalized
# Protein Q96RL6 was successfully normalized
# Protein Q8IVU1 was successfully normalized
# Protein P43307 was successfully normalized
# Protein Q96TA0 was successfully normalized
# Protein P31994 was successfully normalized
# Protein Q9HBG7 was successfully normalized
# Protein P54855 was successfully normalized
# Protein Q6UWD8 was successfully normalized
# Protein Q6UWJ8 was successfully normalized
# Protein O43291 was successfully normalized
# Protein P23470 was successfully normalized
# Protein Q04771 was successfully normalized
# Protein Q9BZZ2 was successfully normalized
# Protein Q9NY72 was successfully normalized
# Protein O75197 was successfully normalized
# Protein Q16820 was successfully normalized
# Protein P15529 was successfully normalized
# Protein P40198 was successfully normalized
# Protein Q6GTX8 was successfully normalized
# Protein Q9UN67 was successfully normalized
# Protein P21802 was successfully normalized
# Protein O75880 was successfully normalized
# Protein P20138 was successfully normalized
# Protein Q5VU97 was successfully normalized
# Protein Q9H5Y7 was successfully normalized
# Protein Q9BTN0 was successfully normalized
# Protein Q96E16 was successfully normalized
# Protein Q9Y6H6 was successfully normalized
# Protein P20916 was successfully normalized
# Protein P57087 was successfully normalized
# Protein O15197 was successfully normalized
# Protein Q13505 was successfully normalized
# Protein Q04900 was successfully normalized
# Protein Q14943 was successfully normalized
# Protein O95168 was successfully normalized
# Protein Q9BXM7 was successfully normalized
# Protein Q5DX21 was successfully normalized
# Protein Q96CU9 was successfully normalized
# Protein O75871 was successfully normalized
# Protein Q9UG56 was successfully normalized
# Protein Q8N386 was successfully normalized
# Protein P08574 was successfully normalized
# Protein Q8N6Y1 was successfully normalized
# Protein Q13444 was successfully normalized
# Protein P15391 was successfully normalized
# Protein Q9Y5E8 was successfully normalized
# Protein Q9Y336 was successfully normalized
# Protein Q9Y286 was successfully normalized
# Protein Q8TCZ2 was successfully normalized
# Protein O60487 was successfully normalized
# Protein Q04912 was successfully normalized
# Protein P11117 was successfully normalized
# Protein O75078 was successfully normalized
# Protein P17301 was successfully normalized
# Protein P01133 was successfully normalized
# Protein Q9Y5E1 was successfully normalized
# Protein Q9BX59 was successfully normalized
# Protein Q9P244 was successfully normalized
# Protein Q8IWT1 was successfully normalized
# Protein P56975 was successfully normalized
# Protein Q8N4L4 was successfully normalized
# Protein Q6ZMC9 was successfully normalized
# Protein Q7Z7H5 was successfully normalized
# Protein Q9Y5F0 was successfully normalized
# Protein Q8WZ59 was successfully normalized
# Protein Q9Y5E7 was successfully normalized
# Protein Q9Y5E6 was successfully normalized
# Protein Q96PC5 was successfully normalized
# Protein Q9Y696 was successfully normalized
# Protein P21860 was successfully normalized
# Protein Q3KR37 was successfully normalized
# Protein Q8WYK1 was successfully normalized
# Protein P40238 was successfully normalized
# Protein P04921 was successfully normalized
# Protein Q9NZA1 was successfully normalized
# Protein Q8N118 was successfully normalized
# Protein P01903 was successfully normalized
# Protein Q9Y5F1 was successfully normalized
# Protein P23467 was successfully normalized
# Protein Q96QU1 was successfully normalized
# Protein Q96FB5 was successfully normalized
# Protein Q5TGI0 was successfully normalized
# Protein P15509 was successfully normalized
# Protein P05362 was successfully normalized
# Protein Q9NYL4 was successfully normalized
# Protein Q9NY15 was successfully normalized
# Protein Q9BY64 was successfully normalized
# Protein Q9HBJ8 was successfully normalized
# Protein Q9NYQ8 was successfully normalized
# Protein Q5T7P8 was successfully normalized
# Protein Q13705 was successfully normalized
# Protein P48357 was successfully normalized
# Protein Q9UBK5 was successfully normalized
# Protein Q6Q8B3 was successfully normalized
# Protein Q8NBR0 was successfully normalized
# Protein Q8IXH8 was successfully normalized
# Protein Q8NAN2 was successfully normalized
# Protein Q6UY11 was successfully normalized
# Protein P48551 was successfully normalized
# Protein O75795 was successfully normalized
# Protein A1L1A6 was successfully normalized
# Protein Q8N292 was successfully normalized
# Protein Q8TDQ1 was successfully normalized
# Protein Q9UIK5 was successfully normalized
# Protein Q9NZ45 was successfully normalized
# Protein O43581 was successfully normalized
# Protein Q96RT6 was successfully normalized
# Protein Q14392 was successfully normalized
# Protein O95833 was successfully normalized
# Protein Q9UIB8 was successfully normalized
# Protein A2RUT3 was successfully normalized
# Protein Q969Z4 was successfully normalized
# Protein Q15116 was successfully normalized
# Protein Q5T1S8 was successfully normalized
# Protein Q3B7T3 was successfully normalized
# Protein Q6ZVL6 was successfully normalized
# Protein Q5SZK8 was successfully normalized
# Protein O43493 was successfully normalized
# Protein Q96LA6 was successfully normalized
# Protein Q5JXA9 was successfully normalized
# Protein P12821 was successfully normalized
# Protein Q12836 was successfully normalized
# Protein Q13145 was successfully normalized
# Protein P43308 was successfully normalized
# Protein Q9Y6Q6 was successfully normalized
# Protein Q9H6D8 was successfully normalized
# Protein Q9H0Q3 was successfully normalized
# Protein Q9C091 was successfully normalized
# Protein Q9P2J2 was successfully normalized
# Protein Q6PEX7 was successfully normalized
# Protein P10966 was successfully normalized
# Protein P08922 was successfully normalized
# Protein Q8NC54 was successfully normalized
# Protein P09619 was successfully normalized
# Protein Q9NYZ4 was successfully normalized
# Protein P40200 was successfully normalized
# Protein P49771 was successfully normalized
# Protein Q6PJG9 was successfully normalized
# Protein Q6UXD1 was successfully normalized
# Protein Q15256 was successfully normalized
# Protein Q5SY80 was successfully normalized
# Protein P28068 was successfully normalized
# Protein A6NJW9 was successfully normalized
# Protein Q5VUB5 was successfully normalized
# Protein Q9H195 was successfully normalized
# Protein Q5VY43 was successfully normalized
# Protein Q96H15 was successfully normalized
# Protein Q9UN72 was successfully normalized
# Protein Q9Y5H7 was successfully normalized
# Protein Q8NCW0 was successfully normalized
# Protein Q92824 was successfully normalized
# Protein Q9BVK6 was successfully normalized
# Protein Q92896 was successfully normalized
# Protein Q96IX5 was successfully normalized
# Protein Q6UWW9 was successfully normalized
# Protein Q9H0V9 was successfully normalized
# Protein P01909 was successfully normalized
# Protein P05106 was successfully normalized
# Protein Q6UWV2 was successfully normalized
# Protein Q9UF33 was successfully normalized
# Protein Q8N7X8 was successfully normalized
# Protein P10321 was successfully normalized
# Protein Q9ULK6 was successfully normalized
# Protein Q96NY7 was successfully normalized
# Protein P10912 was successfully normalized
# Protein P51841 was successfully normalized
# Protein O14967 was successfully normalized
# Protein Q86XS8 was successfully normalized
# Protein Q9Y5F3 was successfully normalized
# Protein Q5TGZ0 was successfully normalized
# Protein Q96JP9 was successfully normalized
# Protein B8ZZ34 was successfully normalized
# Protein Q86TY3 was successfully normalized
# Protein Q9UKQ2 was successfully normalized
# Protein Q9UBN6 was successfully normalized
# Protein Q9BWV2 was successfully normalized
# Protein Q9NQX5 was successfully normalized
# Protein Q5T292 was successfully normalized
# Protein P09958 was successfully normalized
# Protein Q13261 was successfully normalized
# Protein O95196 was successfully normalized
# Protein P07766 was successfully normalized
# Protein Q9BWL3 was successfully normalized
# Protein O75054 was successfully normalized
# Protein Q9Y5R2 was successfully normalized
# Protein O75144 was successfully normalized
# Protein Q5VX71 was successfully normalized
# Protein Q5VZ72 was successfully normalized
# Protein Q9Y6X5 was successfully normalized
# Protein Q6NT55 was successfully normalized
# Protein Q9UJQ1 was successfully normalized
# Protein A8MVS5 was successfully normalized
# Protein Q9Y5H6 was successfully normalized
# Protein A8MVW0 was successfully normalized
# Protein Q68D85 was successfully normalized
# Protein P06127 was successfully normalized
# Protein Q9UN74 was successfully normalized
# Protein A0A1B0GV90 was successfully normalized
# Protein Q8NB59 was successfully normalized
# Protein Q8WZ04 was successfully normalized
# Protein Q9ULC0 was successfully normalized
# Protein Q6UXM1 was successfully normalized
# Protein P08575 was successfully normalized
# Protein P29320 was successfully normalized
# Protein Q86UW2 was successfully normalized
# Protein Q9P0K1 was successfully normalized
# Protein Q9NPG4 was successfully normalized
# Protein P16234 was successfully normalized
# Protein Q6H3X3 was successfully normalized
# Protein Q13477 was successfully normalized
# Protein Q9Y5I0 was successfully normalized
# Protein Q9UN73 was successfully normalized
# Protein Q8N126 was successfully normalized
# Protein P36888 was successfully normalized
# Protein O75882 was successfully normalized
# Protein Q01973 was successfully normalized
# Protein A0A1B0GWG4 was successfully normalized
# Protein P13762 was successfully normalized
# Protein P30273 was successfully normalized
# Protein O00478 was successfully normalized
# Protein Q13683 was successfully normalized
# Protein Q92537 was successfully normalized
# Protein Q5VV63 was successfully normalized
# Protein P52429 was successfully normalized
# Protein Q9UNE0 was successfully normalized
# Protein O14944 was successfully normalized
# Protein P50895 was successfully normalized
# Protein Q13797 was successfully normalized
# Protein Q9H1U4 was successfully normalized
# Protein Q8IVY1 was successfully normalized
# Protein Q5JX69 was successfully normalized
# Protein O60449 was successfully normalized
# Protein Q9Y5H8 was successfully normalized
# Protein Q8TED1 was successfully normalized
# Protein Q96A26 was successfully normalized
# Protein O75077 was successfully normalized
# Protein A8MWY0 was successfully normalized
# Protein Q9UKJ8 was successfully normalized
# Protein Q96PD2 was successfully normalized
# Protein Q7Z6M3 was successfully normalized
# Protein A0A1B0GTW7 was successfully normalized
# Protein Q9BSJ5 was successfully normalized
# Protein Q9UKF5 was successfully normalized
# Protein Q52LC2 was successfully normalized
# Protein Q5VYJ5 was successfully normalized
# Protein P18084 was successfully normalized
# Protein Q15768 was successfully normalized
# Protein Q9BXJ7 was successfully normalized
# Protein O75509 was successfully normalized
# Protein Q8WVV5 was successfully normalized
# Protein Q9BWV1 was successfully normalized
# Protein Q6UXE8 was successfully normalized
# Protein B4DS77 was successfully normalized
# Protein Q5JX71 was successfully normalized
# Protein Q8TCW7 was successfully normalized
# Protein Q96PQ1 was successfully normalized
# Protein Q96KV6 was successfully normalized
# Protein Q8WW62 was successfully normalized
# Protein Q9ULI3 was successfully normalized
# Protein Q7Z7M0 was successfully normalized
# Protein Q9P2V4 was successfully normalized
# Protein P43630 was successfully normalized
# Protein Q07699 was successfully normalized
# Protein P15813 was successfully normalized
# Protein P38484 was successfully normalized
# Protein Q14773 was successfully normalized
# Protein Q8NFT8 was successfully normalized
# Protein O43556 was successfully normalized
# Protein Q96LU7 was successfully normalized
# Protein P78410 was successfully normalized
# Protein Q8NC24 was successfully normalized
# Protein O15079 was successfully normalized
# Protein Q8IYR6 was successfully normalized
# Protein Q6P1S2 was successfully normalized
# Protein Q8NC67 was successfully normalized
# Protein Q9NPH3 was successfully normalized
# Protein Q13651 was successfully normalized
# Protein Q9Y493 was successfully normalized
# Protein Q8N8F7 was successfully normalized
# Protein P07202 was successfully normalized
# Protein Q29980 was successfully normalized
# Protein O76036 was successfully normalized
# Protein Q8TAB3 was successfully normalized
# Protein Q24JP5 was successfully normalized
# Protein P04629 was successfully normalized
# Protein Q3MIX3 was successfully normalized
# Protein Q8IYJ0 was successfully normalized
# Protein P06756 was successfully normalized
# Protein Q9H013 was successfully normalized
# Protein Q6XYQ8 was successfully normalized
# Protein Q5TH69 was successfully normalized
# Protein Q8N6K0 was successfully normalized
# Protein P16066 was successfully normalized
# Protein Q9Y5I3 was successfully normalized
# Protein Q4V9L6 was successfully normalized
# Protein Q14242 was successfully normalized
# Protein P15260 was successfully normalized
# Protein Q86YT9 was successfully normalized
# Protein P55808 was successfully normalized
# Protein Q9Y5Z0 was successfully normalized
# Protein P20963 was successfully normalized
# Protein O60313 was successfully normalized
# Protein O15173 was successfully normalized
# Protein P17181 was successfully normalized
# Protein O15455 was successfully normalized
# Protein Q8WWB7 was successfully normalized
# Protein A0A2R8YCJ5 was successfully normalized
# Protein Q96TC7 was successfully normalized
# Protein Q5XG99 was successfully normalized
# Protein O00264 was successfully normalized
# Protein Q8NEA5 was successfully normalized
# Protein P36897 was successfully normalized
# Protein P34925 was successfully normalized
# Protein P40259 was successfully normalized
# Protein Q68DV7 was successfully normalized
# Protein Q8IUW5 was successfully normalized
# Protein Q9Y3B3 was successfully normalized
# Protein O75445 was successfully normalized
# Protein O75310 was successfully normalized
# Protein Q8N5K1 was successfully normalized
# Protein O75324 was successfully normalized
# Protein Q6UXL0 was successfully normalized
# Protein A6NF34 was successfully normalized
# Protein P31512 was successfully normalized
# Protein P13688 was successfully normalized
# Protein A0A1B0GTY4 was successfully normalized
# Protein Q6UXV1 was successfully normalized
# Protein O75309 was successfully normalized
# Protein Q96DB9 was successfully normalized
# Protein Q16586 was successfully normalized
# Protein O00391 was successfully normalized
# Protein Q9NTN9 was successfully normalized
# Protein Q5VWK5 was successfully normalized
# Protein Q9Y5I2 was successfully normalized
# Protein Q07011 was successfully normalized
# Protein Q86VH5 was successfully normalized
# Protein Q86VH4 was successfully normalized
# Protein Q8TCP9 was successfully normalized
# Protein Q8NFR9 was successfully normalized
# Protein Q14DG7 was successfully normalized
# Protein Q8N131 was successfully normalized
# Protein Q8IZU9 was successfully normalized
# Protein Q9UJA9 was successfully normalized
# Protein Q9H251 was successfully normalized
# Protein P14679 was successfully normalized
# Protein Q86SJ6 was successfully normalized
# Protein Q9P0J0 was successfully normalized
# Protein O95976 was successfully normalized
# Protein P13473 was successfully normalized
# Protein P16284 was successfully normalized
# Protein Q96A33 was successfully normalized
# Protein Q8NAU1 was successfully normalized
# Protein Q96QE4 was successfully normalized
# Protein Q6UXD5 was successfully normalized
# Protein Q9UPX0 was successfully normalized
# Protein O43169 was successfully normalized
# Protein A6NLX4 was successfully normalized
# Protein Q86YD5 was successfully normalized
# Protein P22455 was successfully normalized
# Protein P05556 was successfully normalized
# Protein Q9Y5Y7 was successfully normalized
# Protein Q9UQC9 was successfully normalized
# Protein P26010 was successfully normalized
# Protein Q0VDE8 was successfully normalized
# Protein P13612 was successfully normalized
# Protein Q9C0I4 was successfully normalized
# Protein P56199 was successfully normalized
# Protein A0A5F9ZH02 was successfully normalized
# Protein Q53EL9 was successfully normalized
# Protein Q93033 was successfully normalized
# Protein Q70CQ3 was successfully normalized
# Protein A0A1B0GUU1 was successfully normalized
# Protein Q3ZCQ3 was successfully normalized
# Protein Q9H6Y7 was successfully normalized
# Protein A0A0U1RRA0 was successfully normalized
# Protein Q96JX3 was successfully normalized
# Protein A0A1B0GVN3 was successfully normalized
# Protein P0C6S8 was successfully normalized
# Protein Q3B7S5 was successfully normalized
# Protein Q8NC42 was successfully normalized
# Protein Q92617 was successfully normalized
# Protein C9JG80 was successfully normalized
# Protein Q13410 was successfully normalized
# Protein Q13443 was successfully normalized
# Protein Q6UX27 was successfully normalized
# Protein A8MXV6 was successfully normalized
# Protein Q6GPH6 was successfully normalized
# Protein Q7Z3B0 was successfully normalized
# Protein Q9Y3A6 was successfully normalized
# Protein Q9NPR2 was successfully normalized
# Protein Q9NX94 was successfully normalized
# Protein Q9Y5F7 was successfully normalized
# Protein Q13349 was successfully normalized
# Protein Q01638 was successfully normalized
# Protein Q9H3T2 was successfully normalized
# Protein Q9Y225 was successfully normalized
# Protein Q9HAV5 was successfully normalized
# Protein Q8IYS0 was successfully normalized
# Protein P54710 was successfully normalized
# Protein P17813 was successfully normalized
# Protein Q99650 was successfully normalized
# Protein P56817 was successfully normalized
# Protein Q99965 was successfully normalized
# Protein P09564 was successfully normalized
# Protein Q29983 was successfully normalized
# Protein Q08554 was successfully normalized
# Protein Q8TB96 was successfully normalized
# Protein P15812 was successfully normalized
# Protein O00592 was successfully normalized
# Protein Q8IX05 was successfully normalized
# Protein E5RHQ5 was successfully normalized
# Protein O42043 was successfully normalized
# Protein Q6PCB8 was successfully normalized
# Protein P10721 was successfully normalized
# Protein Q6IEE7 was successfully normalized
# Protein Q9H9V4 was successfully normalized
# Protein P26951 was successfully normalized
# Protein Q6ZSJ9 was successfully normalized
# Protein Q9HBB8 was successfully normalized
# Protein Q9UM44 was successfully normalized
# Protein P25189 was successfully normalized
# Protein Q96AW1 was successfully normalized
# Protein O60500 was successfully normalized
# Protein P56134 was successfully normalized
# Protein Q13586 was successfully normalized
# Protein Q902F9 was successfully normalized
# Protein O14836 was successfully normalized
# Protein Q02505 was successfully normalized
# Protein Q9H8M9 was successfully normalized
# Protein A6NMS7 was successfully normalized
# Protein A6NM11 was successfully normalized
# Protein Q9HAT1 was successfully normalized
# Protein A6NM62 was successfully normalized
# Protein Q3SXY7 was successfully normalized
# Protein P09848 was successfully normalized
# Protein Q7L985 was successfully normalized
# Protein Q9Y5I1 was successfully normalized
# Protein P09669 was successfully normalized
# Protein Q6ZS62 was successfully normalized
# Protein Q01974 was successfully normalized
# Protein P0DP72 was successfully normalized
# Protein Q9BZV3 was successfully normalized
# Protein Q8WWG1 was successfully normalized
# Protein Q13873 was successfully normalized
# Protein Q99467 was successfully normalized
# Protein P20333 was successfully normalized
# Protein Q92813 is not in ESM1b database
# Protein Q8N387 was successfully normalized
# Protein Q8N441 was successfully normalized
# Protein O15247 was successfully normalized
# Protein Q96LC7 was successfully normalized
# Protein Q9UGN4 was successfully normalized
# Protein O14668 was successfully normalized
# Protein P36537 was successfully normalized
# Protein P01906 was successfully normalized
# Protein P49895 is not in ESM1b database
# Protein Q9HCN6 was successfully normalized
# Protein P08648 was successfully normalized
# Protein Q8WXI7 was successfully normalized
# Protein Q92643 was successfully normalized
# Protein O15165 was successfully normalized
# Protein Q8N3G9 was successfully normalized
# Protein Q9C0B7 was successfully normalized
# Protein B0FP48 was successfully normalized
# Protein E5RIL1 was successfully normalized
# Protein P15151 was successfully normalized
# Protein Q9UDW1 was successfully normalized
# Protein O75438 was successfully normalized
# Protein P78357 was successfully normalized
# Protein Q9UHF4 was successfully normalized
# Protein Q7Z6W1 was successfully normalized
# Protein P56378 was successfully normalized
# Protein Q8WUT4 was successfully normalized
# Protein Q9NQ60 was successfully normalized
# Protein Q86VR7 was successfully normalized
# Protein P24071 was successfully normalized
# Protein Q8NER5 was successfully normalized
# Protein P05107 was successfully normalized
# Protein A0A0K2S4Q6 was successfully normalized
# Protein Q9Y5I4 was successfully normalized
# Protein Q96LL3 was successfully normalized
# Protein P26012 was successfully normalized
# Protein P14784 was successfully normalized
# Protein P29017 was successfully normalized
# Protein Q6PIZ9 was successfully normalized
# Protein Q58EX2 was successfully normalized
# Protein Q14126 was successfully normalized
# Protein P60507 was successfully normalized
# Protein Q7Z692 was successfully normalized
# Protein Q9HBE5 was successfully normalized
# Protein Q7Z2Q7 was successfully normalized
# Protein Q6UXG3 was successfully normalized
# Protein A2RRL7 was successfully normalized
# Protein Q9Y3Q7 was successfully normalized
# Protein A5PLK6 was successfully normalized
# Protein Q9Y5H9 was successfully normalized
# Protein P08514 was successfully normalized
# Protein Q96BF3 was successfully normalized
# Protein Q96I36 was successfully normalized
# Protein P51511 was successfully normalized
# Protein Q9Y3P8 was successfully normalized
# Protein Q08334 was successfully normalized
# Protein O60602 was successfully normalized
# Protein Q8NFZ8 was successfully normalized
# Protein A8MTT3 was successfully normalized
# Protein Q8N9R8 was successfully normalized
# Protein Q8TC41 was successfully normalized
# Protein Q8WUY8 was successfully normalized
# Protein Q9NQG6 was successfully normalized
# Protein P20645 was successfully normalized
# Protein Q9Y5T4 was successfully normalized
# Protein Q15155 was successfully normalized
# Protein Q5JPE7 was successfully normalized
# Protein P69849 was successfully normalized
# Protein Q5T7R7 was successfully normalized
# Protein A8MZ97 was successfully normalized
# Protein Q9UKX5 was successfully normalized
# Protein P36896 was successfully normalized
# Protein Q6UX71 was successfully normalized
# Protein O71037 was successfully normalized
# Protein P61565 was successfully normalized
# Protein P61566 was successfully normalized
# Protein Q69384 was successfully normalized
# Protein P61567 was successfully normalized
# Protein Q902F8 was successfully normalized
# Protein Q9UKH3 was successfully normalized
# Protein Q8WWQ8 was successfully normalized
# Protein P27824 was successfully normalized
# Protein P16471 was successfully normalized
# Protein O14523 was successfully normalized
# Protein Q99706 was successfully normalized
# Protein P78536 was successfully normalized
# Protein P27037 was successfully normalized
# Protein A6NFR6 was successfully normalized
# Protein Q8N967 was successfully normalized
# Protein Q8ND94 was successfully normalized
# Protein Q01113 was successfully normalized
# Protein P19256 was successfully normalized
# Protein P22794 was successfully normalized
# Protein Q8WVX9 was successfully normalized
# Protein Q8NI17 was successfully normalized
# Protein Q8N6P7 was successfully normalized
# Protein P32927 was successfully normalized
# Protein Q9Y2G1 was successfully normalized
# Protein O95256 was successfully normalized
# Protein O43567 was successfully normalized
# Protein Q9Y5H5 was successfully normalized
# Protein O75121 was successfully normalized
# Protein O00445 was successfully normalized
# Protein Q9BQG1 was successfully normalized
# Protein Q9Y3Q3 was successfully normalized
# Protein P82279 was successfully normalized
# Protein Q86UQ5 was successfully normalized
# Protein Q96KC8 was successfully normalized
# Protein Q02846 was successfully normalized
# Protein Q14627 was successfully normalized
# Protein Q96G30 was successfully normalized
# Protein Q96F05 was successfully normalized
# Protein A6NL88 was successfully normalized
# Protein Q76MJ5 was successfully normalized
# Protein Q4G0I0 was successfully normalized
# Protein Q9H3S1 was successfully normalized
# Protein Q9UKF2 was successfully normalized
# Protein Q6ZTQ4 was successfully normalized
# Protein P50402 was successfully normalized
# Protein Q8NI28 was successfully normalized
# Protein P60602 was successfully normalized
# Protein A8MRT5 was successfully normalized
# Protein Q4LDR2 was successfully normalized
# Protein Q9Y6W8 was successfully normalized
# Protein A8K4G0 was successfully normalized
# Protein Q9NX95 was successfully normalized
# Protein P55082 was successfully normalized
# Protein P38570 was successfully normalized
# Protein Q5SZI1 was successfully normalized
# Protein P37173 was successfully normalized
# Protein Q9BY71 was successfully normalized
# Protein Q8NFY4 was successfully normalized
# Protein Q9HCU0 was successfully normalized
# Protein Q6UWL6 was successfully normalized
# Protein Q9BQE4 is not in ESM1b database
# Protein Q86YD3 was successfully normalized
# Protein A6NI73 was successfully normalized
# Protein P43629 was successfully normalized
# Protein P37287 was successfully normalized
# Protein P16662 was successfully normalized
# Protein Q6ZMQ8 was successfully normalized
# Protein Q9P246 was successfully normalized
# Protein P20702 was successfully normalized
# Protein Q4ZG55 was successfully normalized
# Protein O00481 was successfully normalized
# Protein Q8TEB7 was successfully normalized
# Protein Q8IW00 was successfully normalized
# Protein Q6UWM9 was successfully normalized
# Protein Q8NAC3 was successfully normalized
# Protein P12074 was successfully normalized
# Protein Q86T13 was successfully normalized
# Protein P98187 was successfully normalized
# Protein Q86UP6 was successfully normalized
# Protein P53708 was successfully normalized
# Protein Q496F6 was successfully normalized
# Protein Q6UXG2 was successfully normalized
# Protein Q8N8N0 was successfully normalized
# Protein A0A1B0GW64 was successfully normalized
# ...
# Protein P58658 was successfully normalized
# Protein P13598 was successfully normalized
# Protein P0CF51 was successfully normalized
# Protein Q86YC3 was successfully normalized
# Protein A0A286YFK9 was successfully normalized
# Protein Q8N149 was successfully normalized
# Protein P20701 was successfully normalized
# Protein Q9NX14 was successfully normalized
# Protein A0A1B0GTU2 was successfully normalized
# Protein P02724 was successfully normalized
# Protein Q86WK7 was successfully normalized
# Protein A0A1B0GUW7 was successfully normalized
# Protein Q9BVW6 was successfully normalized
# Protein Q9BT76 was successfully normalized
# Protein Q6V0I7 was successfully normalized
# Protein Q6NUS8 was successfully normalized
# Protein P56937 was successfully normalized
# Protein Q8N766 was successfully normalized
# Protein P18564 was successfully normalized
# Protein P48060 was successfully normalized
# Protein P21579 was successfully normalized
# Protein P16144 was successfully normalized
# Protein Q9UKU0 was successfully normalized
# Protein Q8TBM8 was successfully normalized
# Protein O14672 was successfully normalized
# Protein P19320 was successfully normalized
# Protein Q9HD87 was successfully normalized
# Protein P80370 was successfully normalized
# Protein Q9Y6D0 is not in ESM1b database
# Protein Q9UBI4 was successfully normalized
# Protein Q5SSG8 was successfully normalized
# Protein A0A1B0GVT2 was successfully normalized
# Protein Q08708 was successfully normalized
# Protein Q6GMR7 was successfully normalized
# Protein O60603 was successfully normalized
# Protein P06028 was successfully normalized
# Protein Q6MZM0 was successfully normalized
# Protein P58550 was successfully normalized
# Protein Q6UWF3 was successfully normalized
# Protein P14060 was successfully normalized
# Protein Q9NZU0 was successfully normalized
# Protein Q9BZL3 was successfully normalized
# Protein P78423 was successfully normalized
# Protein Q16549 was successfully normalized
# Protein O60309 was successfully normalized
# Protein A0A096LP01 was successfully normalized
# Protein O15533 was successfully normalized
# Protein Q9UK23 was successfully normalized
# Protein Q96LA5 was successfully normalized
# Protein P07949 was successfully normalized
# Protein Q08ET2 was successfully normalized
# Protein A6H8M9 was successfully normalized
# Protein Q8NBV8 was successfully normalized
# Protein P31785 was successfully normalized
# Protein Q9Y624 was successfully normalized
# Protein Q14C87 was successfully normalized
# Protein Q9BZD6 was successfully normalized
# Protein Q9NZU1 was successfully normalized
# Protein Q9BRQ8 was successfully normalized
# Protein Q7Z6J6 was successfully normalized
# Protein Q15904 was successfully normalized
# Protein O14949 was successfully normalized
# Protein Q8N3T6 was successfully normalized
# Protein P0DPE3 was successfully normalized
# Protein Q9H9P2 was successfully normalized
# Protein P0C7P4 was successfully normalized
# Protein Q9Y5F6 was successfully normalized
# Protein Q9P283 was successfully normalized
# Protein Q9BR10 was successfully normalized
# Protein Q6UY18 was successfully normalized
# Protein Q96F46 was successfully normalized
# Protein Q96GP6 was successfully normalized
# Protein Q6ZWK4 was successfully normalized
# Protein Q9NZ53 was successfully normalized
# Protein B6A8C7 was successfully normalized
# Protein Q9H158 was successfully normalized
# Protein Q8IUY3 was successfully normalized
# Protein Q5JTH9 was successfully normalized
# Protein Q6PI73 was successfully normalized
# Protein Q6UXU6 was successfully normalized
# Protein Q8TB68 was successfully normalized
# Protein Q96KJ4 was successfully normalized
# Protein Q8N114 was successfully normalized
# Protein Q8NDY8 was successfully normalized
# Protein Q96FE5 was successfully normalized
# Protein Q14162 was successfully normalized
# Protein Q86XM0 was successfully normalized
# Protein A2RU48 was successfully normalized
# Protein Q92542 was successfully normalized
# Protein P22309 was successfully normalized
# Protein Q9HAW8 was successfully normalized
# Protein P35503 was successfully normalized
# Protein P22310 was successfully normalized
# Protein P35504 was successfully normalized
# Protein P19224 was successfully normalized
# Protein Q9HAW7 was successfully normalized
# Protein Q9HAW9 was successfully normalized
# Protein O60656 was successfully normalized
# Protein Q8IYS2 was successfully normalized
# Protein P60606 was successfully normalized
# Protein A6NCI5 was successfully normalized
# Protein P10176 was successfully normalized
# Protein Q8NI60 was successfully normalized
# Protein P0C2S0 was successfully normalized
# Protein P59901 was successfully normalized
# Protein Q7Z3D4 was successfully normalized
# Protein Q9NVM1 was successfully normalized
# Protein Q9UMF0 was successfully normalized
# Protein Q9P0T7 was successfully normalized
# Protein O75460 was successfully normalized
# Protein Q13018 was successfully normalized
# Protein Q13591 was successfully normalized
# Protein Q9HBV2 was successfully normalized
# Protein Q6P995 was successfully normalized
# Protein P0DI80 was successfully normalized
# Protein Q6PHW0 was successfully normalized
# Protein Q8IU57 was successfully normalized
# Protein O95470 was successfully normalized
# Protein Q8TEF2 was successfully normalized
# Protein Q14802 was successfully normalized
# Protein Q8TF66 was successfully normalized
# Protein Q8IV31 was successfully normalized
# Protein Q96KF7 was successfully normalized
# Protein O75976 was successfully normalized
# Protein Q86WK6 was successfully normalized
# Protein Q9Y5U5 was successfully normalized
# Protein Q86YA3 was successfully normalized
# Protein P42701 was successfully normalized
# Protein Q6UWI4 was successfully normalized
# Protein Q9NXS2 was successfully normalized
# Protein Q4G0T1 was successfully normalized
# Protein Q16880 was successfully normalized
# Protein P53801 was successfully normalized
# Protein O60488 was successfully normalized
# Protein E2RYF6 was successfully normalized
# Protein Q6ZWL3 was successfully normalized
# Protein P26006 was successfully normalized
# Protein Q9H665 was successfully normalized
# Protein Q6PJW8 was successfully normalized
# Protein Q9NQ34 was successfully normalized
# Protein Q3SXP7 was successfully normalized
# Protein P08684 was successfully normalized
# Protein P13591 was successfully normalized
# Protein Q9NZN1 was successfully normalized
# Protein A6NKW6 was successfully normalized
# Protein Q8NBU5 was successfully normalized
# Protein Q02487 was successfully normalized
# Protein O43914 was successfully normalized
# Protein Q8IUK5 was successfully normalized
# Protein A0PJX4 was successfully normalized
# Protein Q13113 was successfully normalized
# Protein Q86WC4 was successfully normalized
# Protein Q9NUV7 was successfully normalized
# Protein O75578 was successfully normalized
# Protein P55160 was successfully normalized
# Protein Q96DD7 was successfully normalized
# Protein Q96L08 was successfully normalized
# Protein F2Z333 was successfully normalized
# Protein Q8IWR1 was successfully normalized
# Protein O95944 was successfully normalized
# Protein Q8WWF3 was successfully normalized
# Protein Q6ZU64 was successfully normalized
# Protein Q86UE6 was successfully normalized
# Protein P60509 was successfully normalized
# Protein P12319 was successfully normalized
# Protein P36894 was successfully normalized
# Protein P04843 was successfully normalized
# Protein A0A1B0GV85 was successfully normalized
# Protein A6NFE2 was successfully normalized
# Protein O75631 was successfully normalized
# Protein Q9NQG1 was successfully normalized
# Protein Q8TDY8 was successfully normalized
# Protein Q8TD07 was successfully normalized
# Protein Q8N109 was successfully normalized
# Protein Q8NHK3 was successfully normalized
# Protein O75074 was successfully normalized
# Protein Q6ZSY5 was successfully normalized
# Protein P24311 was successfully normalized
# Protein P33121 was successfully normalized
# Protein A2VDJ0 was successfully normalized
# Protein Q969W9 was successfully normalized
# Protein Q6ZUT9 was successfully normalized
# Protein Q9HB29 was successfully normalized
# Protein Q9NWQ8 was successfully normalized
# Protein Q3KNT9 was successfully normalized
# Protein Q9UKB5 was successfully normalized
# Protein Q8WWF5 was successfully normalized
# Protein P32926 was successfully normalized
# Protein Q7Z4F1 was successfully normalized
# Protein Q02221 was successfully normalized
# Protein Q5VTT2 was successfully normalized
# Protein Q9BSE4 was successfully normalized
# Protein P54756 was successfully normalized
# Protein Q9NSI5 was successfully normalized
# Protein Q9H756 was successfully normalized
# Protein Q13478 was successfully normalized
# Protein A8MXK1 was successfully normalized
# Protein Q86SJ2 was successfully normalized
# Protein Q96N35 was successfully normalized
# Protein A8MWV9 was successfully normalized
# Protein Q8N350 was successfully normalized
# Protein Q96N68 was successfully normalized
# Protein Q96J42 was successfully normalized
# Protein Q9NR97 was successfully normalized
# Protein P16410 was successfully normalized
# Protein P01732 was successfully normalized
# Protein O95573 was successfully normalized
# Protein A6NDA9 was successfully normalized
# Protein Q86XT9 was successfully normalized
# Protein Q9N2K0 was successfully normalized
# Protein Q9BT88 was successfully normalized
# Protein Q7Z5N4 was successfully normalized
# Protein Q969N2 was successfully normalized
# Protein O00220 was successfully normalized
# Protein P04234 was successfully normalized
# Protein Q01344 was successfully normalized
# Protein P60508 was successfully normalized
# Protein A6NFU0 was successfully normalized
# Protein F5H4A9 was successfully normalized
# Protein Q14CZ8 was successfully normalized
# Protein Q5TF21 was successfully normalized
# Protein Q9BXR5 was successfully normalized
# Protein P06133 was successfully normalized
# Protein P26439 was successfully normalized
# Protein Q99795 was successfully normalized
# Protein Q93038 was successfully normalized
# Protein Q8N1N2 was successfully normalized
# Protein Q9BSF4 was successfully normalized
# Protein Q9BZG2 was successfully normalized
# Protein Q9H819 was successfully normalized
# Protein Q8TF08 was successfully normalized
# Protein P62341 is not in ESM1b database
# Protein Q4G1C9 was successfully normalized
# Protein Q5VU65 was successfully normalized
# Protein Q99665 was successfully normalized
# Protein Q8N9F0 was successfully normalized
# Protein Q9BZ11 was successfully normalized
# Protein O43677 was successfully normalized
# Protein Q9BQD7 was successfully normalized
# Protein Q9H1E5 was successfully normalized
# Protein Q15392 was successfully normalized
# Protein Q86UE4 was successfully normalized
# Protein Q9NY47 was successfully normalized
# Protein F7VJQ1 was successfully normalized
# Protein Q14574 was successfully normalized
# Protein Q8TBE3 was successfully normalized
# Protein Q86WI1 was successfully normalized
# Protein Q75NE6 was successfully normalized
# Protein Q8NEW7 was successfully normalized
# Protein Q9BQI7 was successfully normalized
# Protein Q8N4K4 was successfully normalized
# Protein Q6ZSA7 was successfully normalized
# Protein Q9H553 was successfully normalized
# Protein Q9H2E6 was successfully normalized
# Protein Q15884 was successfully normalized
# Protein Q9ULC5 was successfully normalized
# Protein Q96EX1 was successfully normalized
# Protein Q6UWB1 was successfully normalized
# Protein Q01151 was successfully normalized
# Protein Q0P670 was successfully normalized
# Protein Q9Y320 was successfully normalized
# Protein P49788 was successfully normalized
# Protein Q16821 was successfully normalized
# Protein Q8N0Z9 was successfully normalized
# Protein Q2I0M4 was successfully normalized
# Protein Q8NCQ3 was successfully normalized
# Protein Q17R55 was successfully normalized
# Protein P47985 was successfully normalized
# Protein A2A2Y4 was successfully normalized
# Protein Q9H6B9 was successfully normalized
# Protein Q99102 was successfully normalized
# Protein Q9NP80 was successfully normalized
# Protein Q5BVD1 was successfully normalized
# Protein Q9NU53 was successfully normalized
# Protein O60462 was successfully normalized
# Protein Q9NP60 was successfully normalized
# Protein Q9H3N1 was successfully normalized
# Protein Q147U7 was successfully normalized
# Protein Q8N9M5 was successfully normalized
# Protein Q5VT99 was successfully normalized
# Protein Q8WWU5 was successfully normalized
# Protein Q9Y442 was successfully normalized
# Protein Q96BY9 was successfully normalized
# Protein B6SEH8 was successfully normalized
# Protein Q92854 was successfully normalized
# Protein Q9Y6F6 was successfully normalized
# Protein Q03167 was successfully normalized
# Protein Q71H61 was successfully normalized
# Protein Q8IXX5 was successfully normalized
# Protein Q1AE95 was successfully normalized
# Protein Q6UXK2 was successfully normalized
# Protein Q86SU0 was successfully normalized
# Protein Q5JRM2 was successfully normalized
# Protein Q9P0V8 was successfully normalized
# Protein Q9NXE4 was successfully normalized
# Protein Q7Z419 was successfully normalized
# Protein Q9Y561 was successfully normalized
# Protein Q99062 was successfully normalized
# Protein Q96T52 was successfully normalized
# Protein Q8ND61 was successfully normalized
# Protein Q6V0L0 was successfully normalized
# Protein Q9NSK7 was successfully normalized
# Protein O95169 was successfully normalized
# Protein A6NHS7 was successfully normalized
# Protein P14406 was successfully normalized
# Protein Q2WGJ9 was successfully normalized
# Protein O15394 was successfully normalized
# Protein Q6ZRH7 was successfully normalized
# Protein Q9NS64 was successfully normalized
# Protein Q8N7C0 was successfully normalized
# Protein Q86WR0 was successfully normalized
# Protein H3BV60 was successfully normalized
# Protein Q53RT3 was successfully normalized
# Protein Q6ISU1 was successfully normalized
# Protein K7EJ46 was successfully normalized
# Protein P60059 was successfully normalized
# Protein Q9P2B2 was successfully normalized
# Protein Q9Y2C9 was successfully normalized
# Protein Q66K14 was successfully normalized
# Protein Q9BQA9 was successfully normalized
# Protein Q9NPB0 was successfully normalized
# Protein O95167 was successfully normalized
# Protein P08637 was successfully normalized
# Protein O14931 was successfully normalized
# Protein O14786 was successfully normalized
# Protein Q9H6X2 was successfully normalized
# Protein P61550 was successfully normalized
# Protein Q8N326 was successfully normalized
# Protein Q9H0H0 was successfully normalized
# Protein P36941 was successfully normalized
# Protein Q6P4H8 was successfully normalized
# Protein A0AVI2 was successfully normalized
# Protein Q15738 was successfully normalized
# Protein P06340 was successfully normalized
# Protein Q96GQ5 was successfully normalized
# Protein Q68CR1 was successfully normalized
# Protein A0A1B0GVQ0 was successfully normalized
# Protein Q9NVI7 was successfully normalized
# Protein Q9H0A3 was successfully normalized
# Protein Q9BXS4 was successfully normalized
# Protein Q8NDB6 was successfully normalized
# Protein Q9HBL6 was successfully normalized
# Protein P0DTF9 was successfully normalized
# Protein O75787 was successfully normalized
# Protein Q9N2J8 was successfully normalized
# Protein Q969P0 was successfully normalized
# Protein P09693 was successfully normalized
# Protein L0R6Q1 was successfully normalized
# Protein O95237 was successfully normalized
# Protein O15482 was successfully normalized
# Protein Q9UK28 was successfully normalized
# Protein Q02413 was successfully normalized
# Protein P58335 was successfully normalized
# Protein Q86U02 was successfully normalized
# Protein Q9NPA0 was successfully normalized
# Protein Q9NYK1 was successfully normalized
# Protein P07359 was successfully normalized
# Protein Q3SY77 was successfully normalized
# Protein Q5SGD2 was successfully normalized
# Protein Q8TEM1 was successfully normalized
# Protein Q9UQF0 was successfully normalized
# Protein Q9NZJ5 was successfully normalized
# Protein P0DPA2 was successfully normalized
# Protein Q4KMG9 was successfully normalized
# Protein P03928 was successfully normalized
# Protein Q5UCC4 was successfully normalized
# Protein Q9NR96 was successfully normalized
# Protein Q96JJ7 was successfully normalized
# Protein Q15399 was successfully normalized
# Protein A0A0D9SF12 was successfully normalized
# Protein Q9BZ97 was successfully normalized

# %% [markdown]
# #### Pipeline for both Models
#   compute:
#   - standard deviation, varianz, mean, median, max, min per residue
#   - the 10 most pathogenic variants per TMD-JMD region
#   - per

# %%
# Define function

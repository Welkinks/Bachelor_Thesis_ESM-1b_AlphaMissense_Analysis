# %%
# --- Project Setup ---
from setup_notebook import setup_project_root
setup_project_root()

from src.plotting.rank_dotplot import plot_rank_dotplot
import pandas as pd
import numpy as np

# %%
plot_rank_dotplot(model="ESM", alpha=0.01, sample="human", sample_size=100, save=True)
# Out:
# Reading ESM1b scores: 100%|██████████| 100/100 [00:01<00:00, 99.82it/s]
# ✅ Rank Dotplot saved to 'results/images/5.1.Ranking Dotplot/ESM_Rank_Dotplot_Sample_Size_100.png'.
# /Users/doma/Documents/Bachelor_Arbeit/Code/src/plotting/rank_dotplot.py:233: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_rank_dotplot(model="AlphaMissense", alpha=0.01, sample_size=100, save=False)
# Out:
# Reading AlphaMissense scores: 100%|██████████| 100/100 [00:01<00:00, 73.94it/s]
# /Users/doma/Documents/Bachelor_Arbeit/Code/src/plotting/rank_dotplot.py:233: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

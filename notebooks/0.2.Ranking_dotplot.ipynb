# %%
# --- Project Setup ---
from setup_notebook import setup_project_root
setup_project_root()

from src.plotting.rank_dotplot import plot_rank_dotplot

# %%
plot_rank_dotplot(model="ESM", alpha=0.0025, sample="human", sample_size=202, save=False)
# Out:
# Reading ESM1b scores: 100%|██████████| 202/202 [00:02<00:00, 75.40it/s]
# /Users/doma/Documents/Bachelor_Arbeit/Code/src/plotting/rank_dotplot.py:320: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %%
plot_rank_dotplot(model="AlphaMissense", alpha=0.01, sample_size=20, save=False)
# Out:
# Reading AlphaMissense scores: 100%|██████████| 20/20 [00:00<00:00, 52.04it/s]
# /Users/doma/Documents/Bachelor_Arbeit/Code/src/plotting/rank_dotplot.py:320: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
